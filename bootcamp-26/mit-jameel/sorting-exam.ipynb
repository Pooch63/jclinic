# %% [markdown]
# # Experience Evaluation Test
#
# Welcome! This is a 5 question long "exam" that we will use to guage how experienced you are at coding and Python. Try your best on this exam and don't feel pressured to finish all the questions; this will only be used to sort you into respective cohorts for more experienced and less experienced programmers, so that everyone can make the most of their learning at this bootcamp. So remember, this is not a graded exam!
#
# Note that agentic coding tools like Claude Code or Cursor as well as AI/LLMs are not permitted for this exam, but you may use the Python documentation which can be found here: https://docs.python.org/3/. Websites like StackOverflow, W3, and GeeksForGeeks are also not permitted.
#
# Try to answer questions as fully as you possibly can. If you cannot come up with the Python representation for a solution to a problem, feel free to put your intuition for the problem in a comment, as we care about both syntactic knowledge as well as problem solving skills.
#
# Make sure to fill in your name in the first Python cell. If you don't, we can't give you credit!
#
# Good luck!

# %%
# YOU MUST FILL THESE VALUES IN
# IF YOU DON'T, WE'LL DEFAULT YOU TO THE BEGINNERS' GROUP
FIRST_NAME = "Example"
LAST_NAME = "Person"

# %%
# ==============================================================================
# PROBLEM 1
# Suggested Time: 3-5 minutes
# ==============================================================================
# Instructions:
# Write a function named `calculate_age` that takes three inputs:
# a student's `name` (str), their `birth_year` (int), and the
# `current_year` (int).
#
# The function should calculate the student's age and return a specific
# greeting string formatted like this:
# "Hello [name], you are [age] years old!"
#
# Example:
# calculate_age("Alex", 2010, 2026) -> "Hello Alex, you are 16 years old!"
# ==============================================================================

def calculate_age(name: str, birth_year: int, current_year: int) -> str:
    # Put your code here
    pass

print(calculate_age("Alex", 2010, 2026))  # Expected: "Hello Alex, you are 16 years old!"

# %%
# ==============================================================================
# PROBLEM 2
# Suggested Time: 3-5 minutes
# ==============================================================================
# Instructions:
# Write a function named `count_even_odd` that takes in one input:
# a list of numbers (list[int]). The function should return a tuple containing two integers:
# the first integer is the count of even numbers in the list, and the second integer is the count of odd numbers.
#
# Example:
# count_even_odd([1, 2, 3, 4, 5]) -> (2, 3)
#
# Hint:
# You can return 2 values from a function using a tuple, like this:
# `return (even_count, odd_count)`
# or simply `return even_count, odd_count`.
# ==============================================================================

def count_even_odd(numbers: list[int]) -> tuple[int, int]:
    # Put your code here
    pass

print(count_even_odd([1, 2, 3, 4, 5]))  # Expected: (2, 3)

# %%
# ==============================================================================
# PROBLEM 3
# Suggested Time: 8-10 minutes
# ==============================================================================
# Instructions:
# Write a function named `track_word_frequency` that takes two inputs:
# a list of strings called `words` (list[str]), and a string called `target` (str).
#
# The function should count how many times the `target` word appears in the list.
# The function must operate with case-insensitive matching. For example, "Apple", "apple",
# and "APPLE" should all be treated as the exact same word.
#
# Example:
# track_word_frequency(["Apple", "banana", "APPLE", "cherry"], "apple") -> 2
# track_word_frequency(["blue", "red", "green"], "yellow") -> 0
# ==============================================================================

def track_word_frequency(words: list[str], target: str) -> int:
    # Put your code here
    pass

print(track_word_frequency(["Apple", "banana", "APPLE", "cherry"], "apple"))  # Expected: 2
print(track_word_frequency(["blue", "red", "green"], "yellow"))  # Expected: 0

# %%
# ==============================================================================
# PROBLEM 4
# Suggested Time: 12-15 minutes
# ==============================================================================
# Instructions:
# Write a function named `find_second_largest` that takes a list of integers
# called `nums` (list[int]).
#
# The function must find and return the second largest *unique* number in the list.
# If the list does not have a second largest unique number (e.g., it has fewer
# than 2 unique numbers or all the numbers are the same), the function should return None.
#
# You are NOT allowed to use Python's built-in sorting
# methods (like `.sort()` or `sorted()`). You must solve this by iterating
# through the list.
#
# Examples:
# find_second_largest([10, 20, 4, 45, 99, 99]) -> 45
# find_second_largest([5, 5, 5]) -> None
# find_second_largest([12]) -> None
# ==============================================================================

def find_second_largest(nums: list[int]) -> int | None:
    # Put your code here
    pass


print(find_second_largest([10, 20, 4, 45, 99, 99]))  # Expected: 45
print(find_second_largest([5, 5, 5]))  # Expected: None
print(find_second_largest([12]))  # Expected: None

# %%
# ==============================================================================
# PROBLEM 5
# Suggested Time: 15-20 minutes
# ==============================================================================
# To preface, this is a fun challenge problem that we don't expect most people to solve fully.
#
# Instructions:
# Write a function named `find_target_pair` that takes two inputs:
# a list of integers called `numbers` (list[int]) and a single integer called `target` (int).
#
# The function should look for two DISTINCT elements in the list that add up
# to exactly equal the `target` value.
#
# - If a pair is found, return their values as a tuple sorted in ascending order:
#   (smaller_value, larger_value)
# - If no such pair exists, return None.
# - You cannot use the exact same element twice to reach the target (e.g., if
#   numbers is [3] and target is 6, that is invalid). However, if the list
#   contains duplicate numbers (e.g., [3, 3]), using both is valid.
#
# *Solve this problem with a time complexity better than O(n^2).
# You can't have a loop inside another loop. Hint: could a dictionary be useful? *
#
# Example:
# find_target_pair([2, 7, 11, 15], 9) -> (2, 7) because 2 + 7 = 9
# find_target_pair([3, 2, 4], 6) -> (2, 4) because 2 + 4 = 6
# find_target_pair([1, 2, 3], 7) -> None
# ==============================================================================

def find_target_pair(numbers: list[int], target: int) -> tuple[int, int] | None:
    # Put your code here
    pass


print(find_target_pair([2, 7, 11, 15], 9))  # Expected: (2, 7)
print(find_target_pair([3, 2, 4], 6))  # Expected
print(find_target_pair([1, 2, 3], 7))  # Expected: None
